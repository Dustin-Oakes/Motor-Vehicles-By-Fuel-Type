# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from api_keys import gmaps_key

# %%
# Import clean car data
car_data_df = pd.read_csv("../DataSource/clean_car_data.csv")
car_data_df.head()
# Out:
#    Unnamed: 0  VIN (1-10)     County       City State  Postal Code  \
# 0           1  5YJXCBE27J     Island  Greenbank    WA        98253
# 1           8  1N4BZ0CP8H     Chelan  Wenatchee    WA        98801
# 2          10  WVWKR7AU3K  Snohomish    Edmonds    WA        98026
# 3          11  5YJ3E1EB0J     Island    Clinton    WA        98236
# 4          13  5YJ3E1EBXL  Snohomish      Brier    WA        98036
#
#    Model Year        Make    Model           Electric Vehicle Type  \
# 0        2018       TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 1        2017      NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 2        2019  VOLKSWAGEN   E-GOLF  Battery Electric Vehicle (BEV)
# 3        2018       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 4        2020       TESLA  MODEL 3  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible             107
# 2           Clean Alternative Fuel Vehicle Eligible             125
# 3           Clean Alternative Fuel Vehicle Eligible             215
# 4           Clean Alternative Fuel Vehicle Eligible             322
#
#    Legislative District  DOL Vehicle ID          Vehicle Location  \
# 0                  10.0       326880081    (-122.575569 48.08489)
# 1                  12.0       192768747   (-120.336499 47.425146)
# 2                  32.0       477565112   (-122.333046 47.829439)
# 3                  10.0       476402678      (-122.35803 47.9796)
# 4                   1.0       103288153   (-122.281856 47.811678)
#
#    2020 Census Tract
# 0       5.302997e+10
# 1       5.300796e+10
# 2       5.306105e+10
# 3       5.302997e+10
# 4       5.306105e+10

# %%
# Create a new dataframe to hold only the data that I plan to use
reduced_car_data_df = car_data_df[["City", "Vehicle Location"]]
reduced_car_data_df.head()
# Out:
#         City          Vehicle Location
# 0  Greenbank    (-122.575569 48.08489)
# 1  Wenatchee   (-120.336499 47.425146)
# 2    Edmonds   (-122.333046 47.829439)
# 3    Clinton      (-122.35803 47.9796)
# 4      Brier   (-122.281856 47.811678)

# %%
# Groupby Location (count)
heat_data_df = reduced_car_data_df.groupby(reduced_car_data_df["Vehicle Location"], as_index=False).count()
heat_data_df.head()
# Out:
#            Vehicle Location  City
# 0     (-102.69968 22.95716)     7
# 1      (-117.06882 47.7251)    20
# 2     (-117.07351 47.22679)     3
# 3       (-117.0768 46.9101)     9
# 4   (-117.083224 47.660645)   114

# %%
# Reduce to significant data (>1500 for test, use ~200 on Actual)
filtered_heat_data_df = heat_data_df.loc[heat_data_df['City'] > 1500]
filtered_heat_data_df.head()
# Out:
#              Vehicle Location  City
# 211   (-122.042724 47.623594)  1539
# 224   (-122.122018 47.678465)  2802
# 228   (-122.132064 47.759381)  1626
# 230   (-122.151342 47.560192)  1798
# 239   (-122.188994 47.678406)  2018

# %%
# Extract Vehicle Location into useable tuples
#complete_heat_data_df = pd.merge(filtered_heat_data_df, filtered_heat_data_df["Vehicle Location"].str.split(' ', expand=True), how="left", on=['index', 'index'])

# %%
# Configure the map plot
gmaps.configure(api_key= gmaps_key)
heatMapBase = gmaps.figure(center= (47.5, -120), zoom_level= 6.5)

# Add the heatmap layer
#heatMapLayer = gmaps.heatmap_layer(heat_data_df["Vehicle Location"], weights= heat_data_df["City"], dissipating= False, max_intensity= 10, point_radius= 1)
#heatMapBase.add_layer(heatMapLayer)

# Display the map
heatMapBase
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\gmaps\locations.py in locations_to_list(locations)
#      10     try:
# ---> 11         location_tuples = locations.itertuples()  # locations is a dataframe
#      12         locations_as_list = [
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#
# AttributeError: 'Series' object has no attribute 'itertuples'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17260\3528674116.py in <module>
#       4
#       5 # Add the heatmap layer
# ----> 6 heatMapLayer = gmaps.heatmap_layer(heat_data_df["Vehicle Location"], weights= heat_data_df["City"], dissipating= False, max_intensity= 10, point_radius= 1)
#       7 #heatMapBase.add_layer(heatMapLayer)
#       8
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#    1077             for key, value in kwargs.items():
#    1078                 if self.has_trait(key):
# -> 1079                     setattr(self, key, value)
#    1080                 else:
#    1081                     # passthrough args that don't set traits to super
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     604             raise TraitError('The "%s" trait is read-only.' % self.name)
#     605         else:
# --> 606             self.set(obj, value)
#     607
#     608     def _validate(self, obj, value):
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#    2649             return super().set(obj, [value])
#    2650         else:
# -> 2651             return super().set(obj, value)
#    2652
#    2653
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     578
#     579     def set(self, obj, value):
# --> 580         new_value = self._validate(obj, value)
#     581         try:
#     582             old_value = obj._trait_values[self.name]
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     610             return value
#     611         if hasattr(self, 'validate'):
# --> 612             value = self.validate(obj, value)
#     613         if obj._cross_validation_lock is False:
#     614             value = self._cross_validate(obj, value)
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      22         if value is None:
#      23             return super(LocationArray, self).validate(obj, value)
# ---> 24         locations_as_list = locations_to_list(value)
#      25         for location in locations_as_list:
#      26             latitude, longitude = location
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\gmaps\locations.py in locations_to_list(locations)
#      17         locations_as_list = [
#      18             (latitude, longitude) for (latitude, longitude)
# ---> 19             in locations
#      20         ]
#      21     return locations_as_list
#
# c:\Users\oakes\anaconda3\envs\PythonData\lib\site-packages\gmaps\locations.py in <listcomp>(.0)
#      16     except AttributeError:
#      17         locations_as_list = [
# ---> 18             (latitude, longitude) for (latitude, longitude)
#      19             in locations
#      20         ]
#
# ValueError: too many values to unpack (expected 2)
